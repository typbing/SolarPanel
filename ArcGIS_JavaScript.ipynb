# %% [markdown]
# <center>
#     <h2 style="color:  #008080; font-family: Arial, sans-serif; font-size: 32px; padding: 10px;">
#         Week 11: ArcGIS API for JavaScript
#     </h2>
# </center>

# %% [markdown]
# <a href="https://colab.research.google.com/github/gisynw/ssj-30262/blob/main/docs/Lectures/Week 11_JavaScript/ArcGIS_JavaScript.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" style="height: 30px;"/>
# </a>
# &nbsp &nbsp
# <a href="./Week 11_JavaScript/ArcGIS_JavaScript.ipynb" target="_blank">
#   <img src="https://img.icons8.com/?size=100&id=108635&format=png&color=000000" alt="Download" style="height: 40px;"/>
#  </a>

# %% [markdown]
# ## ArcGIS JavaScript API Documentation

# %% [markdown]
# [API's software development kit (SDK)](https://developers.arcgis.com/javascript/latest/) provide many sample code to demonstrate how to accomplist a interactive map with the API. A good way for learning the API, espically for the beginner is to find a sample that fit your needs and midify it based on your requirements.

# %% [markdown]
# JavaScript API in ArcGIS Pro has contents but not limited to below:
#
# 1. Key features
# 2. Install and Set up
# 3. ...

# %% [markdown]
# ### API Reference
#
# Referecne > Core API Reference

# %% [markdown]
# ### Sample Code

# %% [markdown]
# - Check the code in Sandbox
#
# You can modify the code and see the change immediately appear on the right side
#
# basemap: "dark-gray"
# zoom = 10
# center : []

# %% [markdown]
# ### JavaScript Github

# %% [markdown]
# [JavaScript ArcGIS Pro Github Documentation](https://github.com/Esri/arcgis-js-api)

# %% [markdown]
# ## Setup API

# %% [markdown]
# ## Web Page Component

# %% [markdown]
# ### MapView
#
# [Create a 2D map](https://developers.arcgis.com/javascript/latest/sample-code/intro-map-components/)
#
# 1. Define a basemap
#
# ![image.png](attachment:image.png)
#
# 2. MapView display map in 2D
#
# ![image-2.png](attachment:image-2.png)
#
# 3. SceneView display map in 3D
#
# [Create a 3D map](https://developers.arcgis.com/javascript/latest/sample-code/intro-sceneview/)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Load the map and mapview modules
#
# - Load modules
# - Creating instance
#
# For the name of the module, you can have any name but make sure it is easier to keep track
#
# The name of the module should be in the same order of module
#
# ```
#   require(["esri/Map", "esri/views/MapView"], (Map, MapView) => {
#         const map = new Map({
#           basemap: "topo-vector"
#         });
#
#         const view = new MapView({
#           container: "viewDiv",
#           map: map,
#           zoom: 4,
#           center: [15, 65] // longitude, latitude
#         });
#       });
# ```

# %% [markdown]
# ### Add layers
#
# `Thank you Dr. John Rogan, for providing the Solar Panel data to enrich my course content! :)`
#
# [Different layers](https://developers.arcgis.com/javascript/latest/api-reference/)
#
# - Check link below to see how the different layers are defined in web map
#
# The below map add the feature layer and GeoJson layer
#
# https://developers.arcgis.com/javascript/latest/sample-code/sandbox/?sample=featurereduction-cluster

# %% [markdown]
# #### Practice 1. Add Feature Layer
#
# Feature layer can be added to the map through ArcGIS Online Service URL
#
# [Feature Layer Documentation](https://developers.arcgis.com/javascript/latest/api-reference/esri-layers-FeatureLayer.html)
#
# Add [Data: Solor Panel](https://clarku.maps.arcgis.com/home/item.html?id=a171604da3dc42b0befc156d8b23b9d5) to the map
#
# 1. Define the module
# 2. Add FeatureLayer
# ```
#    const featureLayer = new FeatureLayer({
#          url:  "https://services5.arcgis.com/FKwcDz27wRAj4HUT/arcgis/rest/services/Solar_Panel_Data/FeatureServer/0"});
# ```
#
# 3. Add FeatureLayer to the Map
# ```
# map.add(featureLayer);
# ```

# %% [markdown]
# ### Map interaction using popups
#
# - Respond to mouse clicks
# - Provides info on
#   - feature attribute
# - Customizable

# %% [markdown]
# #### FeatureLayer has associated popupTemplate property
#
# Check the popupTemplate
# [Property in FeatureLayer](https://developers.arcgis.com/javascript/latest/api-reference/esri-layers-FeatureLayer.html)

# %% [markdown]
# #### Practice 2: Add Popup Windown to FeatureLayer
#
# [Sample Code](https://developers.arcgis.com/javascript/latest/sample-code/intro-popuptemplate/)
#
# - Create a popuptemplate object and add a title
# ```
# const template = { title:"Solar Panel in Providence"};
# ```
#
# - Add content to the PopupTemplate
# Please add two fields `date_built` and `solar_area` based on sample code

# %% [markdown]
# ### Widgets
#
# The LayerList widget display a list of layers and switch/off their visibility.

# %% [markdown]
# #### Practice 4: Add LayerList
#
# [LayerList widget](https://developers.arcgis.com/javascript/latest/sample-code/sandbox/?sample=widgets-layerlist) display a list of layers for your map
#
# Add title property to FeatureLayer can change the layer's name in LayerList

# %% [markdown]
# ### Legend
#
# - Create a legend instance
# - Add legend to view

# %% [markdown]
# #### Practice 5: Add Legend
#
# [Sample Code](https://developers.arcgis.com/javascript/latest/sample-code/sandbox/?sample=widgets-legend)

# %% [markdown]
# ### Renderers
#
# - Define a set of symbols to use for the layer
# - Set the rules on how the symbols are used
#
# First, check the render for [Solar Panel](https://clarku.maps.arcgis.com/home/item.html?id=a171604da3dc42b0befc156d8b23b9d5) in ArcGIS Online
#
# [Renderers](https://developers.arcgis.com/javascript/latest/sample-code/visualization-location-types/) can be accomplished by various property
#
# #### Practice 6: Add Renderers
#
# [Sample Code](https://developers.arcgis.com/javascript/latest/sample-code/visualization-location-types/)

# %% [markdown]
# Lab
#
# https://developers.arcgis.com/javascript/latest/sample-code/popup-multipleelements/
